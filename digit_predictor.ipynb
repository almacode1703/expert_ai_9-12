# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
#      ---------------------------------------- 38.7/38.7 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from scipy) (2.4.0)
# Installing collected packages: scipy
# Successfully installed scipy-1.16.3
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
#      ---------------------------------------- 8.1/8.1 MB 5.9 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#      -------------------------------------- 225.2/225.2 kB 4.6 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
#      ---------------------------------------- 2.3/2.3 MB 7.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
#      ---------------------------------------- 73.8/73.8 kB ? eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from matplotlib) (12.0.0)
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
#      -------------------------------------- 121.8/121.8 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pyparsing-3.3.1
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\codingal\ai-python\ai_expert\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape for ImageDataGenerator (N, H, W, C)
x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

datagen.fit(x_train)

# Build the model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28, 1)),
    layers.Dense(128),
    layers.LeakyReLU(alpha=0.1),
    layers.Dense(64),
    layers.LeakyReLU(alpha=0.1),
    layers.Dense(10, activation='softmax')
])

# Compile
model.compile(
    optimizer='rmsprop',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
model.fit(
    datagen.flow(x_train, y_train, batch_size=32),
    epochs=10
)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")

# Predict
predictions = model.predict(x_test)

# Display first image and prediction
plt.imshow(x_test[0].squeeze(), cmap='gray')
plt.title(f"Predicted: {predictions[0].argmax()}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.8382 - loss: 0.5220
# Epoch 2/10
#  226/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9212 - loss: 0.2666
